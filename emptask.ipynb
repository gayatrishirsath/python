# %%
eid = int(input("Enter Employee ID: "))
ename = input("Enter Employee Name: ")
address = input("Enter Employee Address: ")
mob = input("Enter Mobile Number: ")
salary = float(input("Enter Employee Salary: "))

print("\n----- Employee Details -----")
print(f"Employee ID : {eid}")
print(f"Employee Name : {ename}")
print(f"Employee Address : {address}")
print(f"Mobile Number : {mob}")
print(f"Employee Salary : {salary}")
# Out:
# Enter Employee ID:  101
# Enter Employee Name:  Gayatri
# Enter Employee Address:  Nasik
# Enter Mobile Number:  9089876765
# Enter Employee Salary:  50000
# ----- Employee Details -----
# Employee ID : 101
# Employee Name : Gayatri
# Employee Address : Nasik
# Mobile Number : 9089876765
# Employee Salary : 50000.0
